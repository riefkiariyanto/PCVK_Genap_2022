# %% [markdown]
# <a href="https://colab.research.google.com/github/riefkiariyanto/PCVK_Genap_2022/blob/main/PCVK_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/sample_data/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/sample_data/kitten01.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
plt.imshow(img_gray, cmap='RdYlGn')

# %%
plt.imshow(img_gray, cmap='GnBu')

# %%
black_img3=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img3)

# %%
cv.rectangle(img3,pt1=(450,450),pt2=(400,400),color=(255,0,255),thickness=15)
plt.imshow(img3)

# %%
cv.rectangle(img3,pt1=(100,200),pt2=(200,100),color=(192,37,255),thickness=15)
plt.imshow(img3)

# %%
cv.rectangle(img3,pt1=(100,400),pt2=(200,450),color=(192,142,199),thickness=15)
plt.imshow(img3)

# %%
cv.rectangle(img3,pt1=(500,100),pt2=(400,200),color=(192,142,0),thickness=15)
plt.imshow(img3)

# %%
cv.rectangle(img3,pt1=(300,250),pt2=(320,300),color=(0,142,0),thickness=15)
plt.imshow(img3)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
imgnew = img
imgnewfix = cv.cvtColor(imgnew,cv.COLOR_BGR2RGB)
cv.rectangle(imgnewfix,pt1=(0,500),pt2=(100,600),color=(0,0,255),thickness=15)
plt.imshow(imgnewfix)

# %%
imgtemp = img
imgfix = cv.cvtColor(imgtemp,cv.COLOR_BGR2RGB)
cv.rectangle(imgfix,pt1=(200,10),pt2=(530,300),color=(192,142,199),thickness=15)
cv.circle(imgfix,center=(380,150),radius=150,color=(255,0,0),thickness=8)
plt.imshow(imgfix)

# %%
img_size = img[10:100,10:100]
plt.imshow(img_size)

# %%
img_size2 = img[5:30]
plt.imshow(img_size2, cmap='Greens')
